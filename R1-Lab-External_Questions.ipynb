# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
import numpy as np

# %%
iris = pd.read_csv("Iris.csv")
iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal Length (in cm)    150 non-null float64
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# Observation: Except "Class" column which is an object, all other columns are float type.

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
#print("\t Top 10 samples\n",iris.head(10))  #-- This will consume more space while printing while it prints to output console
print("\t Top 10 samples")  
iris.head(10)  #prints in a neat tabular format for viewing.
# Out:
# 	 Top 10 samples
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# ...

# %%
print("\t Bottom 10 samples")
iris.tail(10)
# Out:
# 	 Bottom 10 samples
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# ...

# %% [markdown]
# ### Find the shape of the dataset

# %%
iris.shape  #shape displays number of rows and columns for the given data set.
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
iris.index = iris["Sepal Length (in cm)"]  #index is set to column values of Sepal length.

# %%
iris.head()  #by default, top 5 data is shown here.
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
print(iris.iloc[:,3:4])
# Out:
#                       Petal width (in cm)
# Sepal Length (in cm)
# 5.1                                   0.2
# 4.9                                   0.2
# 4.7                                   0.2
# 4.6                                   0.2
# 5.0                                   0.2
# 5.4                                   0.4
# 4.6                                   0.3
# 5.0                                   0.2
# 4.4                                   0.2
# 4.9                                   0.1
# 5.4                                   0.2
# 4.8                                   0.2
# 4.8                                   0.1
# 4.3                                   0.1
# 5.8                                   0.2
# 5.7                                   0.4
# 5.4                                   0.4
# 5.1                                   0.3
# 5.7                                   0.3
# 5.1                                   0.3
# 5.4                                   0.2
# ...

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
#print(iris.iloc[:,2:0:-1].head(10))
#iris.drop(['Sepal Length (in cm)'], axis = 1,inplace = True)
#iris.reset_index(drop = True, inplace = True)

#iris[['Sepal Width in (cm)']['Sepal Length (in cm)']]
#iris.head()
print(iris[['Sepal Width in (cm)','Sepal Length (in cm)']].head(10))  #Printing top 10 rows.
# Out:
#                       Sepal Width in (cm)  Sepal Length (in cm)
# Sepal Length (in cm)
# 5.1                                   3.5                   5.1
# 4.9                                   3.0                   4.9
# 4.7                                   3.2                   4.7
# 4.6                                   3.1                   4.6
# 5.0                                   3.6                   5.0
# 5.4                                   3.9                   5.4
# 4.6                                   3.4                   4.6
# 5.0                                   3.4                   5.0
# 4.4                                   2.9                   4.4
# 4.9                                   3.1                   4.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
iris[iris['Class'] == "Iris-setosa"]   #filters only rows that has value "Iris-setosa" and prints it
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1
# 5.4                                    5.4                  3.7
# 4.8                                    4.8                  3.4
# 4.8                                    4.8                  3.0
# ...

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris['SepalExtra'] = iris['Sepal Length (in cm)'] * iris['Sepal Width in (cm)']  #creates a new column in the iris dataframe and multiple and store the value.

#iris['Sepal Length (in cm)'] * iris['Sepal Width (in cm)']

# %%
iris.head()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class  \
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa
#
#                       SepalExtra
# Sepal Length (in cm)
# ...

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
#iris.describe() #-- describe provide five number summary.  Since the ask is only for mean and variance, used below approach.
print("Mean of all the columns except class column\n")
print(iris.mean())
print("Variance of all the columns except class column\n")
print(iris.var())
# Out:
# Mean of all the columns except class column
#
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64
# Variance of all the columns except class column
#
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
#Using lambda function to print two column in the 5th row. 
SepalLenWidth = lambda x : print("Sepal Length",x[0],"\nSepal Width",x[1])

# %%
SepalLenWidth(iris.iloc[4][:2])  #Printing Sepal length and width in 5th row using iloc
# Out:
# Sepal Length 5.0
# Sepal Width 3.6

# %%
#iris.reset_index(drop = True, inplace = True)    # We can also reset index and then try printing below way.
#SepalLenWidth = lambda x,y : print("Sepal Length",x,"\nSepal Width",y)

# %%
#SepalLenWidth(iris.loc[5.0,'Sepal Length (in cm)'], iris.loc[5.0,'Sepal Width in (cm)'] )
# Out:
# Sepal Length 5.0
# Sepal Width 3.6

# %% [markdown]
# Understanding: iloc method is helpful when we have customized index which are not unique.

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
print("Range of all the columns except class column")
iris.max() - iris.min()
# Out:
# Range of all the columns except class column
# Sepal Length (in cm)     3.60
# Sepal Width in (cm)      2.40
# Petal length (in cm)     5.90
# Petal width (in cm)      2.40
# SepalExtra              20.02
# dtype: float64

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris.sort_values('Petal width (in cm)')
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.2                                    5.2                  4.1
# 4.3                                    4.3                  3.0
# 4.9                                    4.9                  3.1
# 4.9                                    4.9                  3.1
# 4.8                                    4.8                  3.0
# 4.9                                    4.9                  3.1
# 5.1                                    5.1                  3.5
# 5.2                                    5.2                  3.5
# 5.2                                    5.2                  3.4
# 4.7                                    4.7                  3.2
# 4.8                                    4.8                  3.1
# 5.5                                    5.5                  4.2
# 5.5                                    5.5                  3.5
# ...

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris.drop('SepalExtra', inplace = True,axis = 1)
iris.head()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2
# 4.9                                    1.4                  0.2
# 4.7                                    1.3                  0.2
# 4.6                                    1.5                  0.2
# 5.0                                    1.4                  0.2

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset = iris.iloc[:10,:3]

# %%
IrisSubset
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1
#
#                       Petal length (in cm)
# Sepal Length (in cm)
# 5.1                                    1.4
# 4.9                                    1.4
# 4.7                                    1.3
# ...

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
hrdata = pd.read_csv("HR_external.txt",delimiter = "\t")

# %%
hrdata.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# ...

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
hrdata.shape
# Out:
# (1470, 35)

# %%
print("No. of rows is",hrdata.shape[0]) 
print("No. of columns is",hrdata.shape[1])
# Out:
# No. of rows is 1470
# No. of columns is 35

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
hrdata.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
hrdata.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# 10     35               1        809           2                16          3
# ...

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
hrdata[hrdata['Gender'] == 1].shape[0]  # Considering chronological order, 1 is assumed as "Female"
# Out:
# 882

# %%
hrdata[hrdata['Gender'] == 2].shape[0]  # Assuming 2 as "Male"
# Out:
# 588

# %%
hrdata[hrdata['Gender'] == 1].shape[0] + hrdata[hrdata['Gender'] == 2].shape[0]
# Out:
# 1470

# %%
hrdata['Gender']=hrdata['Gender'].map({1:"Female",2:"Male"})

# %%
hrdata['Gender'].value_counts()  ## Another way of finding the # of male and female employees.  1: Female and 2: Male. 
#There are 882 female and 588 male employees available in the hr dataset.
# Out:
# Female    882
# Male      588
# Name: Gender, dtype: int64

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
A25,A75 = np.percentile(hrdata['Age'],[75,25])
print(A25," ",A75)

print("Inter Quartile Range", A75- A25)
# Out:
# 43.0   30.0
# Inter Quartile Range -13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
print(hrdata['DailyRate'].mean())
print(hrdata['DailyRate'].median())
print(hrdata['DailyRate'].var())

type(hrdata)
# Out:
# 802.4857142857143
# 802.0
# 162819.59373723628
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# I have made some analysis with respect to attrition and made the below categorical plots as the question is not very specific except on attrition column.

# %%
hrdata.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours StockOptionLevel  \
# 0                         1             80                0
# ...

# %%
sns.countplot(data=hrdata,x="Attrition",hue = "Gender")  #Finding Attrition for both Gender.  
#Since the data is not a balanced set as female employees are more than Male employees, below observation maynot be appropriate.

# %%
pd.crosstab(hrdata['Attrition'],hrdata['Gender'])  # Above is interpretted in table format.
# Out:
# Gender     Female  Male
# Attrition
# No            732   501
# Yes           150    87

# %%
sns.boxplot(data = hrdata, x = "Attrition", y = "DistanceFromHome",hue = "Gender")

# %% [markdown]
# Observation: Attrition rate is high when work location is far away from home.

# %%
sns.catplot(data = hrdata, x = "Attrition", y = "JobSatisfaction", kind = "box")

# %% [markdown]
# Observation: This shows that Attrition rate is high when Job satisfaction is low (less than or equal to 3)

# %%
hrdata[hrdata['Attrition'] == "Yes"]['JobSatisfaction'].count()
# Out:
# 237

# %%
hrdata['JobSatisfaction'].value_counts()
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64

# %%
hrdata['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# Above shows that it is an imbalanced data set.

# %%
sns.catplot(data = hrdata, x = "Attrition", y = "OverTime", kind = "box")

# %% [markdown]
# Observation: Attrition is high due to overtime work.

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
sns.distplot(hrdata['TotalWorkingYears'],hist=True,bins = 10,color="r")  
#Shows right skewness. Most of the employees inthe given dataset falls under 0 - 20 years of experience

# %%
plt.hist(hrdata['TotalWorkingYears'])  #Another way using hist in matplot lib.
# Out:
# (array([165., 357., 437., 155., 119., 107.,  53.,  40.,  24.,  13.]),
#  array([ 0.,  4.,  8., 12., 16., 20., 24., 28., 32., 36., 40.]),
#  <a list of 10 Patch objects>)

# %%
#Below are some of the comparison between experience vs monthly income
plt.scatter(hrdata['TotalWorkingYears'],hrdata['MonthlyIncome'],5)
plt.title("Working Years vs Monthly Income")
plt.xlabel("TotalWorking Years")
plt.ylabel("Monthly Income")
#People having more experience are likely to get more income than who having less experience.
# Out:
# Text(0, 0.5, 'Monthly Income')

# %%
plt.scatter(hrdata['TotalWorkingYears'],hrdata['Age'])
plt.title("Working Years Vs Age")
plt.xlabel("Total Working Years")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# Observation: As age increases,years of working experiences also increase.

# %%
plt.scatter(hrdata['NumCompaniesWorked'],hrdata['TotalWorkingYears'])
plt.title("Year of Experience vs No. of Companies Worked")
plt.xlabel("Companies Worked")
plt.ylabel("TotalWorkingYears")
# Out:
# Text(0, 0.5, 'TotalWorkingYears')
