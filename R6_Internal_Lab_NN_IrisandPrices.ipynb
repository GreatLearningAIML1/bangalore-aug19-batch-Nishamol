# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
from sklearn.model_selection import train_test_split
#Irisds = pd.read_csv(".//prices and iris//iris.csv")
#Irisds.head()

# %%
#Importing from sklearn library.
from sklearn import datasets
Iris=datasets.load_iris()

# %%
type(Iris)
# Out:
# sklearn.utils.Bunch

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
X = Iris.data
y = Iris.target

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,test_size = 0.25)

# %%
ytrain
# Out:
# array([2, 0, 1, 0, 0, 1, 0, 2, 2, 1, 2, 0, 2, 1, 0, 2, 0, 1, 0, 2, 1, 0,
#        2, 0, 1, 1, 1, 2, 0, 2, 1, 1, 1, 1, 0, 2, 0, 1, 2, 2, 0, 1, 2, 2,
#        0, 1, 0, 1, 2, 0, 2, 1, 1, 0, 0, 1, 2, 1, 1, 1, 2, 0, 2, 2, 1, 2,
#        1, 2, 0, 1, 2, 2, 1, 1, 0, 2, 0, 2, 0, 2, 0, 1, 0, 1, 2, 0, 0, 0,
#        0, 0, 2, 2, 0, 1, 1, 1, 2, 1, 1, 2, 1, 0, 2, 0, 0, 1, 2, 1, 0, 2,
#        0, 0])

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
nb_classes = 3
ytrain_copy = ytrain.copy()
ytest_copy = ytest.copy()
target1 = np.array([[ytrain]]).reshape(-1)
target2 = np.array([[ytest]]).reshape(-1)
ytrain = np.eye(3)[target1]
ytest = np.eye(3)[target2]

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
inputshape = Xtrain.shape[1:]
model = tf.keras.models.Sequential([
 # tf.keras.layers.Flatten(input_shape=inputshape),
  tf.keras.layers.Dense(4, input_shape=inputshape, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(60, activation='relu'),
  tf.keras.layers.Dense(30, activation='relu'),
  tf.keras.layers.Dense(3, activation='softmax')
])

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
model.compile(optimizer='SGD',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 60)                300
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                1830
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 93
# =================================================================
# Total params: 2,243
# Trainable params: 2,243
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
model.fit(Xtrain, ytrain, epochs=100)
model.evaluate(Xtest,  ytest, verbose=2)
# Out:
# Train on 112 samples
# Epoch 1/100
# 112/112 [==============================] - 0s 2ms/sample - loss: 1.0807 - accuracy: 0.3125
# Epoch 2/100
# 112/112 [==============================] - 0s 49us/sample - loss: 1.0651 - accuracy: 0.3839
# Epoch 3/100
# 112/112 [==============================] - 0s 53us/sample - loss: 1.0697 - accuracy: 0.3571
# Epoch 4/100
# 112/112 [==============================] - 0s 71us/sample - loss: 1.0752 - accuracy: 0.3393
# Epoch 5/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0763 - accuracy: 0.3214
# Epoch 6/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0749 - accuracy: 0.3214
# Epoch 7/100
# 112/112 [==============================] - 0s 71us/sample - loss: 1.0649 - accuracy: 0.3661
# Epoch 8/100
# 112/112 [==============================] - 0s 45us/sample - loss: 1.0632 - accuracy: 0.3482
# Epoch 9/100
# 112/112 [==============================] - 0s 71us/sample - loss: 1.0675 - accuracy: 0.3214
# Epoch 10/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0700 - accuracy: 0.2946
# Epoch 11/100
# 112/112 [==============================] - 0s 71us/sample - loss: 1.0620 - accuracy: 0.3214
# Epoch 12/100
# 112/112 [==============================] - 0s 53us/sample - loss: 1.0562 - accuracy: 0.3393
# Epoch 13/100
# 112/112 [==============================] - 0s 72us/sample - loss: 1.0616 - accuracy: 0.3304
# Epoch 14/100
# 112/112 [==============================] - 0s 53us/sample - loss: 1.0558 - accuracy: 0.3214
# Epoch 15/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0644 - accuracy: 0.2946
# Epoch 16/100
# 112/112 [==============================] - 0s 71us/sample - loss: 1.0516 - accuracy: 0.3393
# Epoch 17/100
# 112/112 [==============================] - 0s 45us/sample - loss: 1.0552 - accuracy: 0.3036
# Epoch 18/100
# 112/112 [==============================] - 0s 53us/sample - loss: 1.0339 - accuracy: 0.3839
# Epoch 19/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0483 - accuracy: 0.3036
# Epoch 20/100
# 112/112 [==============================] - 0s 53us/sample - loss: 1.0472 - accuracy: 0.2946
# Epoch 21/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0457 - accuracy: 0.3036
# Epoch 22/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0314 - accuracy: 0.3304
# Epoch 23/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0341 - accuracy: 0.3304
# Epoch 24/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0246 - accuracy: 0.3125
# Epoch 25/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0048 - accuracy: 0.3661
# Epoch 26/100
# 112/112 [==============================] - 0s 62us/sample - loss: 1.0262 - accuracy: 0.2857
# Epoch 27/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.9996 - accuracy: 0.3214
# Epoch 28/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.9978 - accuracy: 0.3125
# Epoch 29/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.9741 - accuracy: 0.3661
# Epoch 30/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.9569 - accuracy: 0.4464
# Epoch 31/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.9613 - accuracy: 0.4554
# Epoch 32/100
# 112/112 [==============================] - 0s 45us/sample - loss: 0.9430 - accuracy: 0.5268
# Epoch 33/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.9351 - accuracy: 0.5536
# Epoch 34/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.9454 - accuracy: 0.5268
# Epoch 35/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.9167 - accuracy: 0.5268
# Epoch 36/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.9096 - accuracy: 0.5268
# Epoch 37/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.8813 - accuracy: 0.5982
# Epoch 38/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.8402 - accuracy: 0.5893
# Epoch 39/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.8832 - accuracy: 0.5089
# Epoch 40/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.8316 - accuracy: 0.6250
# Epoch 41/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.8243 - accuracy: 0.6339
# Epoch 42/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.8217 - accuracy: 0.5714
# Epoch 43/100
# 112/112 [==============================] - 0s 44us/sample - loss: 0.8413 - accuracy: 0.5179
# Epoch 44/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.8592 - accuracy: 0.5982
# Epoch 45/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.8178 - accuracy: 0.5625
# Epoch 46/100
# 112/112 [==============================] - 0s 54us/sample - loss: 0.8084 - accuracy: 0.5625
# Epoch 47/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.7880 - accuracy: 0.5804
# Epoch 48/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.7898 - accuracy: 0.5357
# Epoch 49/100
# 112/112 [==============================] - 0s 80us/sample - loss: 0.7997 - accuracy: 0.5357
# Epoch 50/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.7867 - accuracy: 0.5268
# Epoch 51/100
# 112/112 [==============================] - 0s 98us/sample - loss: 0.7911 - accuracy: 0.5446
# Epoch 52/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.7638 - accuracy: 0.5357
# Epoch 53/100
# 112/112 [==============================] - 0s 45us/sample - loss: 0.7635 - accuracy: 0.5357
# Epoch 54/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.7559 - accuracy: 0.5446
# Epoch 55/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.7598 - accuracy: 0.5536
# Epoch 56/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.7816 - accuracy: 0.5179
# Epoch 57/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.6799 - accuracy: 0.6607
# Epoch 58/100
# 112/112 [==============================] - 0s 45us/sample - loss: 0.6878 - accuracy: 0.5804
# Epoch 59/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.7572 - accuracy: 0.6429
# Epoch 60/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6836 - accuracy: 0.5804
# Epoch 61/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.7379 - accuracy: 0.5357
# Epoch 62/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.7487 - accuracy: 0.5268
# Epoch 63/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.7448 - accuracy: 0.5446
# Epoch 64/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.8010 - accuracy: 0.5089
# Epoch 65/100
# 112/112 [==============================] - 0s 98us/sample - loss: 0.7379 - accuracy: 0.6071
# Epoch 66/100
# 112/112 [==============================] - 0s 107us/sample - loss: 0.7071 - accuracy: 0.6429
# Epoch 67/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.7152 - accuracy: 0.5268
# Epoch 68/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.7146 - accuracy: 0.5357
# Epoch 69/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6017 - accuracy: 0.62 - 0s 62us/sample - loss: 0.6789 - accuracy: 0.5714
# Epoch 70/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.7615 - accuracy: 0.4911
# Epoch 71/100
# 112/112 [==============================] - 0s 63us/sample - loss: 0.6900 - accuracy: 0.5714
# Epoch 72/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6898 - accuracy: 0.5536
# Epoch 73/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.7057 - accuracy: 0.5089
# Epoch 74/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6435 - accuracy: 0.5714
# Epoch 75/100
# 112/112 [==============================] - 0s 45us/sample - loss: 0.7041 - accuracy: 0.5982
# Epoch 76/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6532 - accuracy: 0.5804
# Epoch 77/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6941 - accuracy: 0.5536
# Epoch 78/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6168 - accuracy: 0.6607
# Epoch 79/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6483 - accuracy: 0.5536
# Epoch 80/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6751 - accuracy: 0.6339
# Epoch 81/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6617 - accuracy: 0.5536
# Epoch 82/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6952 - accuracy: 0.5357
# Epoch 83/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6441 - accuracy: 0.5893
# Epoch 84/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.5891 - accuracy: 0.7232
# Epoch 85/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.6833 - accuracy: 0.5982
# Epoch 86/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6479 - accuracy: 0.5982
# Epoch 87/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.6601 - accuracy: 0.5893
# Epoch 88/100
# 112/112 [==============================] - 0s 71us/sample - loss: 0.6716 - accuracy: 0.5893
# Epoch 89/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6477 - accuracy: 0.6071
# Epoch 90/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6026 - accuracy: 0.7946
# Epoch 91/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6379 - accuracy: 0.6161
# Epoch 92/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.5673 - accuracy: 0.7679
# Epoch 93/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6843 - accuracy: 0.62 - 0s 62us/sample - loss: 0.6779 - accuracy: 0.6964
# Epoch 94/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6164 - accuracy: 0.6964
# Epoch 95/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6553 - accuracy: 0.5982
# Epoch 96/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.7049 - accuracy: 0.5536
# Epoch 97/100
# 112/112 [==============================] - 0s 62us/sample - loss: 0.6536 - accuracy: 0.6429
# Epoch 98/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6466 - accuracy: 0.6429
# Epoch 99/100
# 112/112 [==============================] - 0s 45us/sample - loss: 0.6153 - accuracy: 0.6429
# Epoch 100/100
# 112/112 [==============================] - 0s 53us/sample - loss: 0.6653 - accuracy: 0.5714
# 38/1 - 0s - loss: 0.4966 - accuracy: 0.8158
# [0.5159237714190232, 0.81578946]

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
print("Features for 1 row",Xtest[2])
classes = model.predict([[Xtest[2]]])
print("Predicted values ",classes)
# Out:
# Features for 1 row [5.8 4.  1.2 0.2]
# Predicted values  [[0.94493634 0.03767908 0.01738469]]

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
print("Features for 1 row",Xtest[2])
print("Actual result",ytest[2])
# Out:
# Features for 1 row [5.8 4.  1.2 0.2]
# Actual result [1. 0. 0.]

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %% [markdown]
# %tensorflow_version 2.x    #Not using this as it is executed in my own laptop with TFv2.0

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %% [markdown]
# #Nisha - skipping as running from personal laptop.
# # run this cell to upload file if you are using google colab
# from google.colab import files
# files.upload()

# %%
prices = pd.read_csv(".//prices and iris//prices.csv")
prices.head()
# Out:
#                   date symbol        open       close         low        high  \
# 0  2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
prices.drop(['date','symbol'],axis = 1, inplace = True)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
del prices1000
prices1000 = prices.loc[:999,:]
prices1000.shape
# Out:
# (1000, 5)

# %%
prices1000.head()
# Out:
#          open       close         low        high     volume
# 0  123.430000  125.839996  122.309998  126.250000  2163600.0
# 1  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2  116.379997  114.949997  114.930000  119.739998  2489500.0
# 3  115.480003  116.620003  113.500000  117.440002  2006300.0
# 4  117.010002  114.970001  114.089996  117.330002  1408600.0

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
features = prices1000[['open', 'close', 'low', 'high']]
features.head(2)
# Out:
#          open       close         low        high
# 0  123.430000  125.839996  122.309998  126.250000
# 1  125.239998  119.980003  119.940002  125.540001

# %%
label = prices1000[['volume']]

# %%
label.head(2)
# Out:
#       volume
# 0  2163600.0
# 1  2386400.0

# %%
label = label/1000000

# %%
label.head(2)
# Out:
#    volume
# 0  2.1636
# 1  2.3864

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
type(features),type(label)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
features = features.to_numpy()
label = label.to_numpy()
type(features),type(label)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
features.dtype, label.dtype
# Out:
# (dtype('float64'), dtype('float64'))

# %%
features = features.astype('float32')
label = label.astype('float32')
features.dtype, label.dtype
# Out:
# (dtype('float32'), dtype('float32'))

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
features1 = tf.math.l2_normalize(
    features,
    axis=None,
    epsilon=1e-12,
    name=None
)

# %%
features1
# Out:
# <tf.Tensor: id=7177, shape=(1000, 4), dtype=float32, numpy=
# array([[0.02202894, 0.02245906, 0.02182905, 0.02253223],
#        [0.02235197, 0.02141321, 0.02140607, 0.02240551],
#        [0.0207707 , 0.02051548, 0.02051192, 0.02137037],
#        ...,
#        [0.00505436, 0.00513467, 0.00499903, 0.00514181],
#        [0.00785282, 0.0079956 , 0.0078082 , 0.00799738],
#        [0.00643931, 0.00662849, 0.00642682, 0.00664455]], dtype=float32)>

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
#tf.zeros([1000, 5], tf.float32)
W = tf.Variable(tf.zeros(shape=[4,1]), name="Weights")
b = tf.Variable(tf.zeros(shape=[1]), name="Bias")
print(W)
print(b)
# Out:
# <tf.Variable 'Weights:0' shape=(4, 1) dtype=float32, numpy=
# array([[0.],
#        [0.],
#        [0.],
#        [0.]], dtype=float32)>
# <tf.Variable 'Bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
@tf.function
def prediction(features1,W,b):
    yPred = tf.add(tf.matmul(features1,W),b,name='output')
    return yPred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
@tf.function
def calloss(label,yPred):
    loss = tf.reduce_mean(tf.square(label-yPred))
    return loss

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(inputs, outputs,W,b,learning_rate):
    with tf.GradientTape() as t:
        t.watch([W,b])
        curr_pred = prediction(inputs,W,b)
        current_loss = calloss(outputs,curr_pred)
    dW, db = t.gradient(current_loss, [W,b])
    W.assign_sub(learning_rate * dW)  #  W = W - lr*dW
    b.assign_sub(learning_rate * db)
    return (W,b)

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):
    W,b = train(features1,label,W,b,0.02)
    print('Current Training loss on iteration',i,calloss(label,prediction(features1,W,b)))
# Out:
# Current Training loss on iteration 0 tf.Tensor(231.15013, shape=(), dtype=float32)
# Current Training loss on iteration 1 tf.Tensor(229.41672, shape=(), dtype=float32)
# Current Training loss on iteration 2 tf.Tensor(227.8193, shape=(), dtype=float32)
# Current Training loss on iteration 3 tf.Tensor(226.34724, shape=(), dtype=float32)
# Current Training loss on iteration 4 tf.Tensor(224.9906, shape=(), dtype=float32)
# Current Training loss on iteration 5 tf.Tensor(223.74037, shape=(), dtype=float32)
# Current Training loss on iteration 6 tf.Tensor(222.5882, shape=(), dtype=float32)
# Current Training loss on iteration 7 tf.Tensor(221.52641, shape=(), dtype=float32)
# Current Training loss on iteration 8 tf.Tensor(220.54791, shape=(), dtype=float32)
# Current Training loss on iteration 9 tf.Tensor(219.64618, shape=(), dtype=float32)
# Current Training loss on iteration 10 tf.Tensor(218.8151, shape=(), dtype=float32)
# Current Training loss on iteration 11 tf.Tensor(218.04932, shape=(), dtype=float32)
# Current Training loss on iteration 12 tf.Tensor(217.34349, shape=(), dtype=float32)
# Current Training loss on iteration 13 tf.Tensor(216.69307, shape=(), dtype=float32)
# Current Training loss on iteration 14 tf.Tensor(216.09369, shape=(), dtype=float32)
# Current Training loss on iteration 15 tf.Tensor(215.54129, shape=(), dtype=float32)
# Current Training loss on iteration 16 tf.Tensor(215.03224, shape=(), dtype=float32)
# Current Training loss on iteration 17 tf.Tensor(214.56306, shape=(), dtype=float32)
# Current Training loss on iteration 18 tf.Tensor(214.1307, shape=(), dtype=float32)
# Current Training loss on iteration 19 tf.Tensor(213.73225, shape=(), dtype=float32)
# Current Training loss on iteration 20 tf.Tensor(213.3651, shape=(), dtype=float32)
# Current Training loss on iteration 21 tf.Tensor(213.02667, shape=(), dtype=float32)
# Current Training loss on iteration 22 tf.Tensor(212.71481, shape=(), dtype=float32)
# Current Training loss on iteration 23 tf.Tensor(212.42744, shape=(), dtype=float32)
# Current Training loss on iteration 24 tf.Tensor(212.16254, shape=(), dtype=float32)
# Current Training loss on iteration 25 tf.Tensor(211.91844, shape=(), dtype=float32)
# Current Training loss on iteration 26 tf.Tensor(211.69344, shape=(), dtype=float32)
# Current Training loss on iteration 27 tf.Tensor(211.48618, shape=(), dtype=float32)
# Current Training loss on iteration 28 tf.Tensor(211.29507, shape=(), dtype=float32)
# Current Training loss on iteration 29 tf.Tensor(211.11899, shape=(), dtype=float32)
# Current Training loss on iteration 30 tf.Tensor(210.95673, shape=(), dtype=float32)
# Current Training loss on iteration 31 tf.Tensor(210.80716, shape=(), dtype=float32)
# Current Training loss on iteration 32 tf.Tensor(210.66934, shape=(), dtype=float32)
# Current Training loss on iteration 33 tf.Tensor(210.5423, shape=(), dtype=float32)
# Current Training loss on iteration 34 tf.Tensor(210.42522, shape=(), dtype=float32)
# Current Training loss on iteration 35 tf.Tensor(210.31732, shape=(), dtype=float32)
# Current Training loss on iteration 36 tf.Tensor(210.21786, shape=(), dtype=float32)
# Current Training loss on iteration 37 tf.Tensor(210.12622, shape=(), dtype=float32)
# Current Training loss on iteration 38 tf.Tensor(210.04173, shape=(), dtype=float32)
# Current Training loss on iteration 39 tf.Tensor(209.96391, shape=(), dtype=float32)
# Current Training loss on iteration 40 tf.Tensor(209.89215, shape=(), dtype=float32)
# Current Training loss on iteration 41 tf.Tensor(209.826, shape=(), dtype=float32)
# Current Training loss on iteration 42 tf.Tensor(209.7651, shape=(), dtype=float32)
# Current Training loss on iteration 43 tf.Tensor(209.70888, shape=(), dtype=float32)
# Current Training loss on iteration 44 tf.Tensor(209.65712, shape=(), dtype=float32)
# Current Training loss on iteration 45 tf.Tensor(209.60938, shape=(), dtype=float32)
# Current Training loss on iteration 46 tf.Tensor(209.56544, shape=(), dtype=float32)
# Current Training loss on iteration 47 tf.Tensor(209.52487, shape=(), dtype=float32)
# Current Training loss on iteration 48 tf.Tensor(209.4875, shape=(), dtype=float32)
# Current Training loss on iteration 49 tf.Tensor(209.4531, shape=(), dtype=float32)
# Current Training loss on iteration 50 tf.Tensor(209.42128, shape=(), dtype=float32)
# Current Training loss on iteration 51 tf.Tensor(209.39203, shape=(), dtype=float32)
# Current Training loss on iteration 52 tf.Tensor(209.36504, shape=(), dtype=float32)
# Current Training loss on iteration 53 tf.Tensor(209.34012, shape=(), dtype=float32)
# Current Training loss on iteration 54 tf.Tensor(209.31721, shape=(), dtype=float32)
# Current Training loss on iteration 55 tf.Tensor(209.2961, shape=(), dtype=float32)
# Current Training loss on iteration 56 tf.Tensor(209.2766, shape=(), dtype=float32)
# Current Training loss on iteration 57 tf.Tensor(209.2586, shape=(), dtype=float32)
# Current Training loss on iteration 58 tf.Tensor(209.24207, shape=(), dtype=float32)
# Current Training loss on iteration 59 tf.Tensor(209.22678, shape=(), dtype=float32)
# Current Training loss on iteration 60 tf.Tensor(209.21269, shape=(), dtype=float32)
# Current Training loss on iteration 61 tf.Tensor(209.19972, shape=(), dtype=float32)
# Current Training loss on iteration 62 tf.Tensor(209.18771, shape=(), dtype=float32)
# Current Training loss on iteration 63 tf.Tensor(209.17667, shape=(), dtype=float32)
# Current Training loss on iteration 64 tf.Tensor(209.1665, shape=(), dtype=float32)
# Current Training loss on iteration 65 tf.Tensor(209.1571, shape=(), dtype=float32)
# Current Training loss on iteration 66 tf.Tensor(209.14847, shape=(), dtype=float32)
# Current Training loss on iteration 67 tf.Tensor(209.14044, shape=(), dtype=float32)
# Current Training loss on iteration 68 tf.Tensor(209.13306, shape=(), dtype=float32)
# Current Training loss on iteration 69 tf.Tensor(209.12625, shape=(), dtype=float32)
# Current Training loss on iteration 70 tf.Tensor(209.12, shape=(), dtype=float32)
# Current Training loss on iteration 71 tf.Tensor(209.11421, shape=(), dtype=float32)
# Current Training loss on iteration 72 tf.Tensor(209.10884, shape=(), dtype=float32)
# Current Training loss on iteration 73 tf.Tensor(209.10391, shape=(), dtype=float32)
# Current Training loss on iteration 74 tf.Tensor(209.09935, shape=(), dtype=float32)
# Current Training loss on iteration 75 tf.Tensor(209.09515, shape=(), dtype=float32)
# Current Training loss on iteration 76 tf.Tensor(209.09128, shape=(), dtype=float32)
# Current Training loss on iteration 77 tf.Tensor(209.08766, shape=(), dtype=float32)
# Current Training loss on iteration 78 tf.Tensor(209.08441, shape=(), dtype=float32)
# Current Training loss on iteration 79 tf.Tensor(209.08131, shape=(), dtype=float32)
# Current Training loss on iteration 80 tf.Tensor(209.07849, shape=(), dtype=float32)
# Current Training loss on iteration 81 tf.Tensor(209.07588, shape=(), dtype=float32)
# Current Training loss on iteration 82 tf.Tensor(209.07344, shape=(), dtype=float32)
# Current Training loss on iteration 83 tf.Tensor(209.07121, shape=(), dtype=float32)
# Current Training loss on iteration 84 tf.Tensor(209.06914, shape=(), dtype=float32)
# Current Training loss on iteration 85 tf.Tensor(209.06723, shape=(), dtype=float32)
# Current Training loss on iteration 86 tf.Tensor(209.06548, shape=(), dtype=float32)
# Current Training loss on iteration 87 tf.Tensor(209.06384, shape=(), dtype=float32)
# Current Training loss on iteration 88 tf.Tensor(209.06232, shape=(), dtype=float32)
# Current Training loss on iteration 89 tf.Tensor(209.0609, shape=(), dtype=float32)
# Current Training loss on iteration 90 tf.Tensor(209.05956, shape=(), dtype=float32)
# Current Training loss on iteration 91 tf.Tensor(209.0584, shape=(), dtype=float32)
# Current Training loss on iteration 92 tf.Tensor(209.05725, shape=(), dtype=float32)
# Current Training loss on iteration 93 tf.Tensor(209.05621, shape=(), dtype=float32)
# Current Training loss on iteration 94 tf.Tensor(209.05527, shape=(), dtype=float32)
# Current Training loss on iteration 95 tf.Tensor(209.05434, shape=(), dtype=float32)
# Current Training loss on iteration 96 tf.Tensor(209.0535, shape=(), dtype=float32)
# Current Training loss on iteration 97 tf.Tensor(209.05275, shape=(), dtype=float32)
# Current Training loss on iteration 98 tf.Tensor(209.05202, shape=(), dtype=float32)
# Current Training loss on iteration 99 tf.Tensor(209.05132, shape=(), dtype=float32)

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
print(f'Updates Weight (W) values are: \n{W.numpy()}')
# Out:
# Updates Weight (W) values are:
# [[-0.00995435]
#  [-0.00950616]
#  [-0.00957756]
#  [-0.00977882]]

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
print(f'Updates Bias(b) value is: \n{b.numpy()}')
# Out:
# Updates Bias(b) value is:
# [5.231433]
